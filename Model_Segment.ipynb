# %%
from PIL import Image
from matplotlib import pyplot as plt
import numpy as np
from lang_sam import LangSAM
import torch
import os
import cv2
from transformers import CLIPImageProcessor, CLIPVisionModelWithProjection
import pandas as pd
import torch
from sklearn.metrics.pairwise import cosine_similarity

# %%
#Configs
# path to directory to dump embeddings
run_id = 'run_1'
# number of frames to extract in a minute
frame_rate = 5
#maxID : number of products to process starting: 1001
max_id = 1999

# %%
def get_device_type() -> str:
    if torch.backends.mps.is_available():
        return "cpu"
    elif torch.cuda.is_available():
        return "cuda"
    else:
        # logging.warning("No GPU found, using CPU instead")
        return "cpu"

# %%
class ObjectDetector:
    def __init__(self):
        self.model = LangSAM(sam_type="sam2.1_hiera_tiny", gdino_type="tiny")
    
    def predict(self, image_pil, text_prompt):
        results = self.model.predict([image_pil], [text_prompt])
        return results
    
    def plot_results(self, image_pil, results, text_prompt):
        
        # Convert the mask to a numpy array
        mask = results[0]['masks'][0]

        # Plot the image
        plt.figure(figsize=(10, 10))
        plt.imshow(image_pil)

        # Plot the bounding box
        box = results[0]['boxes'][0]
        plt.gca().add_patch(plt.Rectangle((box[0], box[1]), box[2] - box[0], box[3] - box[1], edgecolor='red', facecolor='none', linewidth=2))

        # Plot the mask
        plt.imshow(np.ma.masked_where(mask == 0, mask), alpha=0.5, cmap='jet')

        plt.title(f"Prediction for: {text_prompt}")
        plt.axis('off')
        plt.show()

    # given an image and results, hide the mask on the image by making the values zero within the mask
    def hide_mask(self, image_pil, results):
        mask = results[0]['masks'][0]
        image_np = np.array(image_pil)
        image_np[mask == 1] = 0
        return Image.fromarray(image_np)

    def crop_image(self, image_pil, results):
        box = results[0]['boxes'][0]
        cropped_image = image_pil.crop((box[0], box[1], box[2], box[3]))
        return cropped_image
    
    def predict_and_crop_image(self, image_pil, text_prompt):
        results = self.predict(image_pil, text_prompt)
        cropped_image = self.crop_image(image_pil, results)
        return cropped_image

    def show_image(self, image_pil):
        plt.imshow(image_pil)
        plt.axis('off')
        plt.show()

    def resize(self, image_pil, long_side):
        width, height = image_pil.size
        if width > height:
            new_width = long_side
            new_height = int(long_side * height / width)
        else:
            new_height = long_side
            new_width = int(long_side * width / height)
        return image_pil.resize((new_width, new_height))
object_detector = ObjectDetector()

# %%
def extract_frames(video_path, frame_rate):
    video_capture = cv2.VideoCapture(video_path)
    fps = video_capture.get(cv2.CAP_PROP_FPS)
    interval = int(fps / frame_rate)
    frame_number = 0
    frames = []
    while True:
        success, frame = video_capture.read()
        if not success:
            break
        if frame_number % interval == 0:
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(frame_rgb)

        frame_number += 1
    video_capture.release()
    return frames

# %%
def toFilter(path, maxNumber= 1999):
    try:
        number = path.split('_')[0]
        return int(number) <= maxNumber
    except:
        return False

# %%
embeddings = {}
video_frame_map = {}
video_frame_map_cropped = {}
video_frame_map_masked = {}
def load_embeddings():
    path_to_videos = "./sourceDataVideos/"
    videos = os.listdir(path_to_videos)
    # videos = videos[:2]
    print(videos)
    count = 0
    for video in videos:
        try:
            if(not toFilter(video, max_id)):
                continue
            print("--------------------- Processing video: ", count, video)
            count += 1
            video_path = os.path.join(path_to_videos, video)
            frames = extract_frames(video_path, frame_rate)
            print("Number of frames: ", len(frames))
            id = video.split("_")[0]
            frame_number = 0
            for frame in frames:
                print("Processing frame: ", count, frame_number)
                image = Image.fromarray(frame)
                resultsMasked = object_detector.predict(image, "hand, no background, no object")
                masked_image = object_detector.hide_mask(image, resultsMasked)
                cropped_image = object_detector.predict_and_crop_image(masked_image, "object, no hand, no background")
                # inputs = embeddingProcessor(images=cropped_image, return_tensors="pt", padding=True).to(get_device_type())
                # with torch.no_grad():
                #     features = embeddingModel(**inputs)
                #     features.image_embeds = features.image_embeds
                # embeddings[id + "_" + str(frame_number)] = features
                # video_frame_map[id + "_" + str(frame_number)] = image
                video_frame_map_cropped[id + "_" + str(frame_number)] = cropped_image
                # video_frame_map_masked[id + "_" + str(frame_number)] = masked_image
                frame_number += 1
        except Exception as e:
            print("failed processing video",video, e)
load_embeddings()
# Out:
# ['1014_ButterDelite-Biscuit_5.mp4', '1080_Sugar500g-Grains_24.mp4', '1022_Lux-Soap_30.mp4', '1030_SurfExcel-Surf_10.mp4', '1007_XXX-Soap_10.mp4', '1059_TurmericPowder-Spices_5.mp4', '1069_SmallRava1kg-Grains_40.mp4', '1001_Dove-Soap_35.mp4', '1036_Lime-Pickle_10.mp4', '1035_Mango-Pickle_10.mp4', '1039_Wheel-Surf_38.mp4', '1040_XXX-Surf_38.mp4', '1003_Lifeboy-Soap_30.mp4', '1031_Wheel-Surf_10.mp4', '1015_AllRounder-Biscuit_5.mp4', "1011_Mom'sMagic-Biscuit_11.mp4", '1083_ChanaDal500g-Grains_39.mp4', '1073_ChanaDal1kg-Grains_78.mp4', '1055_GodavariGhee-Milk_10.mp4', '1024_Dettol-Soap_10.mp4', '1021_Glucose-Biscuit_5.mp4', '1056_Yippee-Noodles_10.mp4', '1019_KrackJack-Biscuit_10.mp4', '1032_Ariel-Surf_10.mp4', '1018_Glucose-Biscuit_10.mp4', '1034_Tide-Surf_45.mp4', '1016_Oreo-Biscuit_10.mp4', '1042_Parachute-Oil_20.mp4', '1061_NaniGhee-Milk_10.mp4', '1017_KrackJack-Biscuit_5.mp4', '1047_Yippee-Noodles_14.mp4', '1066_GroundNut1kg-Grains_140.mp4', '1062_ChickenMasala-Spices_5.mp4', '1058_Efkay-Tea_10.mp4', '1027_Rin-Surf_10.mp4', '1046_Parachute-Oil_104.mp4', '1048_Maggi-Noodles_5.mp4', '1026_Lux-Soap_10.mp4', '1044_Parachute-Oil_40.mp4', '1065_MoondDal1kg-Grains_140.mp4', '1053_Jeera-Spices_10.mp4', '1050_Kumkum-Temple_5.mp4', "1012_Mom'sMagic-Biscuit_10.mp4", '1054_Jeera-Spices_25.mp4', '1072_GajrajRice1kg-Grains_56.mp4', '1038_RedChilli-Pickle_10.mp4', '1013_ButterDelite-Biscuit_10.mp4', '1005_Santoor-Soap_40.mp4', '1009_Wheel-Soap_10.mp4', '1052_SambarPowder-Spices_10.mp4', '1025_Lux-Soap_10.mp4', '1063_MeatMasala-Spices_5.mp4', '1004_Cinthol-Soap_30.mp4', '1060_Maggi-Noodles_5.mp4', '1023_Santoor-Soap_36.mp4', '.DS_Store', '1051_CorrianderPowder-Spices_5.mp4', '1082_GajrajRice500g-Grains_28.mp4', '1049_MustardSeeds-Spices_5.mp4', '1074_ToorDal500g-Grains_65.mp4', '1079_SmallRava500g-Grains_20.mp4', '1077_IdliRava500g-Grains_22.mp4', '1071_KurnoolRice1kg-Grains_65.mp4', '1041_Wheel-Surf_76.mp4', '1078_GodumaRava500g-Grains_24.mp4', '1008_Diamond-Soap_10.mp4', '1057_RedLabel-Tea_10.mp4', '1045_Parachute-Oil_70.mp4', '1081_KurnoolRice500g-Grains_34.mp4', '1037_Tomato-Pickle_11.mp4', '1002_Cinthol-Soap_10.mp4', '1043_Parachute-Oil_10.mp4', '1067_IdliRava1kg-Grains_44.mp4', '1020_AllRounder-Biscuit_30.mp4', '1006_Rin-Soap_10.mp4', '1068_GodumaRava1kg-Grains_48.mp4', '1029_Tide-Surf_45.mp4', '1070_Sugar1kg-Grains_48.mp4', '1010_Vim-Soap_10.mp4', '1075_MoongDal500g-Grains_70.mp4', '1064_ToorDal1kg-grains_130.mp4', '1033_SurfExcel-Surf_98.mp4', '1076_GroundNut500g-Grains_70.mp4', '1028_SurfExcel-Surf_99.mp4']
# --------------------- Processing video:  0 1014_ButterDelite-Biscuit_5.mp4
# Number of frames:  20
# Processing frame:  1 0
# Predicting 1 masks
# Predicted 1 masks
# /home/shanmukh/miniconda3/envs/billing/lib/python3.11/site-packages/torchvision/transforms/functional.py:154: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   img = torch.from_numpy(pic.transpose((2, 0, 1))).contiguous()
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  1 19
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  1 1080_Sugar500g-Grains_24.mp4
# Number of frames:  16
# Processing frame:  2 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  2 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  2 1022_Lux-Soap_30.mp4
# Number of frames:  29
# Processing frame:  3 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 19
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 20
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 21
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 22
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 23
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 24
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 25
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 26
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 27
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  3 28
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  3 1030_SurfExcel-Surf_10.mp4
# Number of frames:  15
# Processing frame:  4 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  4 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  4 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  4 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  4 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  4 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  4 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  4 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  4 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  4 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  4 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  4 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  4 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  4 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  4 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  4 1007_XXX-Soap_10.mp4
# Number of frames:  52
# Processing frame:  5 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 19
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 20
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 21
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 22
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 23
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 24
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 25
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 26
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 27
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 28
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 29
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 30
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 31
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 32
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 33
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 34
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 35
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 36
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 37
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 38
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 39
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 40
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 41
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 42
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 43
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 44
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 45
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 46
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 47
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 48
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 49
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 50
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  5 51
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  5 1059_TurmericPowder-Spices_5.mp4
# Number of frames:  19
# Processing frame:  6 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  6 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  6 1069_SmallRava1kg-Grains_40.mp4
# Number of frames:  20
# Processing frame:  7 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  7 19
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  7 1001_Dove-Soap_35.mp4
# Number of frames:  40
# Processing frame:  8 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 19
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 20
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 21
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 22
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 23
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 24
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 25
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 26
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 27
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 28
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 29
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 30
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 31
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 32
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 33
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 34
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 35
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 36
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 37
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 38
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  8 39
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  8 1036_Lime-Pickle_10.mp4
# Number of frames:  18
# Processing frame:  9 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  9 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  9 1035_Mango-Pickle_10.mp4
# Number of frames:  17
# Processing frame:  10 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  10 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  10 1039_Wheel-Surf_38.mp4
# Number of frames:  18
# Processing frame:  11 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  11 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  11 1040_XXX-Surf_38.mp4
# Number of frames:  33
# Processing frame:  12 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 19
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 20
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 21
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 22
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 23
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 24
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 25
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 26
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 27
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 28
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 29
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 30
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 31
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  12 32
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  12 1003_Lifeboy-Soap_30.mp4
# Number of frames:  47
# Processing frame:  13 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 19
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 20
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 21
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 22
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 23
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 24
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 25
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 26
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 27
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 28
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 29
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 30
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 31
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 32
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 33
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 34
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 35
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 36
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 37
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 38
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 39
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 40
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 41
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 42
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 43
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 44
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 45
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  13 46
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  13 1031_Wheel-Surf_10.mp4
# Number of frames:  22
# Processing frame:  14 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 19
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 20
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  14 21
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  14 1015_AllRounder-Biscuit_5.mp4
# Number of frames:  34
# Processing frame:  15 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 19
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 20
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 21
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 22
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 23
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 24
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 25
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 26
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 27
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 28
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 29
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 30
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 31
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 32
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  15 33
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  15 1011_Mom'sMagic-Biscuit_11.mp4
# Number of frames:  31
# Processing frame:  16 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 19
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 20
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 21
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 22
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 23
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 24
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 25
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 26
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 27
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 28
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 29
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  16 30
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  16 1083_ChanaDal500g-Grains_39.mp4
# Number of frames:  25
# Processing frame:  17 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  17 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  17 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  17 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  17 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  17 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  17 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  17 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  17 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  17 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  17 10
# ...
# Predicted 1 masks
# Processing frame:  78 23
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 24
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 25
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 26
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 27
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 28
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 29
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 30
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 31
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 32
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 33
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 34
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 35
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 36
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 37
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 38
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 39
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 40
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 41
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 42
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 43
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 44
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 45
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  78 46
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  78 1075_MoongDal500g-Grains_70.mp4
# Number of frames:  19
# Processing frame:  79 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  79 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  79 1064_ToorDal1kg-grains_130.mp4
# Number of frames:  32
# Processing frame:  80 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 19
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 20
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 21
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 22
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 23
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 24
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 25
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 26
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 27
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 28
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 29
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 30
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  80 31
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  80 1033_SurfExcel-Surf_98.mp4
# Number of frames:  26
# Processing frame:  81 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 19
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 20
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 21
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 22
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 23
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 24
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  81 25
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  81 1076_GroundNut500g-Grains_70.mp4
# Number of frames:  19
# Processing frame:  82 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  82 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# --------------------- Processing video:  82 1028_SurfExcel-Surf_99.mp4
# Number of frames:  37
# Processing frame:  83 0
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 1
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 2
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 3
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 4
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 5
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 6
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 7
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 8
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 9
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 10
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 11
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 12
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 13
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 14
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 15
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 16
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 17
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 18
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 19
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 20
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 21
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 22
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 23
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 24
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 25
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 26
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 27
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 28
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 29
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 30
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 31
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 32
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 33
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 34
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 35
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing frame:  83 36
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks

# %%
# images = {}
# image_map = {}
image_cropped_map = {}
# image_masked_map = {}
def load_images():
    path_to_images = "./sourceDataImages/"
    imageDirs = os.listdir(path_to_images)
    print(imageDirs)
    imageDirCount = 0
    for imageDir in imageDirs:
        try:
            if(not toFilter(imageDir, max_id)):
                continue
            print("Processing imageDir: ", imageDirCount)
            imagePaths = os.listdir(os.path.join(path_to_images, imageDir))
            count = 0
            print("Processing imageDir: ", imageDir)
            for imagePath in imagePaths:
                image = Image.open(os.path.join(path_to_images, imageDir, imagePath))
                resultsMasked = object_detector.predict(image, "hand, no background, no object")
                masked_image = object_detector.hide_mask(image, resultsMasked)
                cropped_image = object_detector.predict_and_crop_image(masked_image, "object, no hand, no background")
                # inputs = embeddingProcessor(images=cropped_image, return_tensors="pt", padding=True).to(get_device_type())
                # with torch.no_grad():
                #     features = embeddingModel(**inputs)
                #     features.image_embeds = features.image_embeds
                # images[imageDir + "_" + str(count) ] = features
                # image_map[imageDir + "_" + str(count) ] = image
                image_cropped_map[imageDir + "_" + str(count) ] = cropped_image
                # image_masked_map[imageDir + "_" + str(count)] = masked_image
                count += 1
        except:
            print("Error processing imageDir: ", imageDir)
        imageDirCount += 1
        
load_images()
# Out:
# ['1056', '1016', '1026', '1012', '1019', '1025', '1037', '1035', '1009', '1021', '1051', '1067', '1065', '1042', '1071', '1057', '1070', '1003', '1074', '1058', '1005', '1050', '1046', '1007', '1008', '1032', '1020', '1077', '1036', '1022', '1048', '1055', '1062', '1049', '1023', '1034', '1081', '1045', '1029', '1075', '1054', '1082', '1066', '1064', '1002', '1017', '1024', '1018', '1080', '1011', '1060', '1039', '1030', '.DS_Store', '1078', '1013', '1040', '1061', '1063', '1028', '1015', '1033', '1041', '1038', '1014', '1079', '1043', '1068', '1083', '1076', '1069', '1073', '1010', '1001', '1031', '1044', '1027', '1052', '1072', '1006', '1053', '1047', '1059']
# Processing imageDir:  0
# Processing imageDir:  1056
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  1
# Processing imageDir:  1016
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  2
# Processing imageDir:  1026
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  3
# Processing imageDir:  1012
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  4
# Processing imageDir:  1019
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  5
# Processing imageDir:  1025
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  6
# Processing imageDir:  1037
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  7
# Processing imageDir:  1035
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  8
# Processing imageDir:  1009
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  9
# Processing imageDir:  1021
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  10
# Processing imageDir:  1051
# Predicting 1 masks
# Predicted 1 masks
# Error processing imageDir:  1051
# Processing imageDir:  11
# Processing imageDir:  1067
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  12
# Processing imageDir:  1065
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  13
# Processing imageDir:  1042
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  14
# Processing imageDir:  1071
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  15
# Processing imageDir:  1057
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  16
# Processing imageDir:  1070
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  17
# Processing imageDir:  1003
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  18
# Processing imageDir:  1074
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  19
# Processing imageDir:  1058
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  20
# Processing imageDir:  1005
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  21
# Processing imageDir:  1050
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  22
# Processing imageDir:  1046
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  23
# Processing imageDir:  1007
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  24
# Processing imageDir:  1008
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  25
# Processing imageDir:  1032
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  26
# Processing imageDir:  1020
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  27
# Processing imageDir:  1077
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  28
# Processing imageDir:  1036
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  29
# Processing imageDir:  1022
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Error processing imageDir:  1022
# Processing imageDir:  30
# Processing imageDir:  1048
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  31
# Processing imageDir:  1055
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  32
# Processing imageDir:  1062
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  33
# Processing imageDir:  1049
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  34
# Processing imageDir:  1023
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  35
# Processing imageDir:  1034
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  36
# Processing imageDir:  1081
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  37
# Processing imageDir:  1045
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  38
# Processing imageDir:  1029
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  39
# Processing imageDir:  1075
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  40
# Processing imageDir:  1054
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Error processing imageDir:  1054
# Processing imageDir:  41
# Processing imageDir:  1082
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  42
# Processing imageDir:  1066
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  43
# Processing imageDir:  1064
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  44
# Processing imageDir:  1002
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  45
# Processing imageDir:  1017
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  46
# Processing imageDir:  1024
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  47
# Processing imageDir:  1018
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  48
# Processing imageDir:  1080
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  49
# Processing imageDir:  1011
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  50
# Processing imageDir:  1060
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  51
# Processing imageDir:  1039
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  52
# Processing imageDir:  1030
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  53
# Processing imageDir:  1078
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  54
# Processing imageDir:  1013
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  55
# Processing imageDir:  1040
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  56
# Processing imageDir:  1061
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  57
# Processing imageDir:  1063
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  58
# Processing imageDir:  1028
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  59
# Processing imageDir:  1015
# Predicting 1 masks
# Predicted 1 masks
# Error processing imageDir:  1015
# Processing imageDir:  60
# Processing imageDir:  1033
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  61
# Processing imageDir:  1041
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  62
# Processing imageDir:  1038
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  63
# Processing imageDir:  1014
# Predicting 1 masks
# Predicted 1 masks
# Error processing imageDir:  1014
# Processing imageDir:  64
# Processing imageDir:  1079
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  65
# Processing imageDir:  1043
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  66
# Processing imageDir:  1068
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  67
# Processing imageDir:  1083
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  68
# Processing imageDir:  1076
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  69
# Processing imageDir:  1069
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  70
# Processing imageDir:  1073
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  71
# Processing imageDir:  1010
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  72
# Processing imageDir:  1001
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  73
# Processing imageDir:  1031
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  74
# Processing imageDir:  1044
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  75
# Processing imageDir:  1027
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  76
# Processing imageDir:  1052
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  77
# Processing imageDir:  1072
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  78
# Processing imageDir:  1006
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  79
# Processing imageDir:  1053
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  80
# Processing imageDir:  1047
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Processing imageDir:  81
# Processing imageDir:  1059
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks
# Predicting 1 masks
# Predicted 1 masks

# %%
saveDir = "./SegementedData/InputImages"
if not os.path.exists(saveDir):
    os.makedirs(saveDir)
for key, value in video_frame_map_cropped.items():
    directory = key.split("_")[0]
    number = key.split("_")[1]
    if not os.path.exists(os.path.join(saveDir, directory)):
        os.makedirs(os.path.join(saveDir, directory))
    value.save(os.path.join(os.path.join(saveDir, directory), key + ".png"))

# %%
saveDir = "./SegementedData/OutputImages"
if not os.path.exists(saveDir):
    os.makedirs(saveDir)
for key, value in image_cropped_map.items():
    directory = key.split("_")[0]
    number = key.split("_")[1]
    if not os.path.exists(os.path.join(saveDir, directory)):
        os.makedirs(os.path.join(saveDir, directory))
    value.save(os.path.join(os.path.join(saveDir, directory), key + ".png"))
